# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action="ignore")

# %%
data = pd.read_csv("creditcard.csv")

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
sns.histplot(data=data,x="Time")
plt.title("Distribution of time")
plt.show()

# %%
sns.countplot(data=data,x="Class")
plt.title("Number of fraud vs legit cards")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import regularizers
# Out:
# WARNING:tensorflow:From k:\VS Code Python\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
ann_model  = Sequential([
    Dense(100,activation="relu",input_shape=(30,),kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4)),
    Dense(64,activation="relu",kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4)),
    Dense(1,activation="sigmoid")
])

ann_model.compile(optimizer = 'adam',loss='binary_crossentropy',metrics=['accuracy'])
ann_model.summary()
# Out:
# WARNING:tensorflow:From k:\VS Code Python\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From k:\VS Code Python\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               3100
#
#  dense_1 (Dense)             (None, 64)                6464
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9629 (37.61 KB)
# Trainable params: 9629 (37.61 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
data.shape
# Out:
# (284807, 31)

# %%
fraud = data[data["Class"]==1]
no_fraud = data[data["Class"]==0]
upsampled_fraud = resample(fraud,replace=True,n_samples=no_fraud.shape[0],random_state=42)
upsampled_data = pd.concat([no_fraud,upsampled_fraud])
upsampled_data = upsampled_data.sample(frac=1)

# %%
upsampled_data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
X = upsampled_data.drop(columns="Class")
y = upsampled_data["Class"]

# %%
scaler = MinMaxScaler()
scaler.fit(X)
X.loc[:,:] = scaler.transform(X.loc[:,:])

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 76482   0.327504  0.980261  0.772091  0.803788  0.259606  0.783284  0.293324
# 13381   0.136760  0.977927  0.769104  0.862609  0.319939  0.760395  0.261796
# 137544  0.475803  0.946401  0.776159  0.866214  0.295409  0.773056  0.274659
# 213217  0.805373  0.996282  0.751014  0.818934  0.178486  0.757496  0.259680
# 95534   0.378247  0.978577  0.761233  0.850280  0.251284  0.761512  0.271386
# ...          ...       ...       ...       ...       ...       ...       ...
# 87354   0.356764  0.932432  0.783140  0.843866  0.353305  0.762172  0.273060
# 272150  0.954552  0.990821  0.766473  0.815714  0.287145  0.764703  0.252397
# 191690  0.748709  0.978407  0.799517  0.730635  0.497690  0.776602  0.244440
# 44556   0.243015  0.880717  0.802642  0.758187  0.412230  0.748933  0.252061
# 123270  0.444853  0.976685  0.778811  0.813725  0.341145  0.770483  0.254899
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 76482   0.263714  0.793478  0.455167  ...  0.580532  0.559527  0.490076
# 13381   0.261925  0.784698  0.530918  ...  0.579285  0.558297  0.507582
# 137544  0.267052  0.790338  0.424281  ...  0.579076  0.565432  0.536176
# 213217  0.257609  0.786017  0.420736  ...  0.574768  0.559362  0.508523
# 95534   0.260279  0.788313  0.503065  ...  0.580935  0.560682  0.519700
# ...          ...       ...       ...  ...       ...       ...       ...
# 87354   0.258730  0.785093  0.444419  ...  0.584661  0.566835  0.533075
# 272150  0.265357  0.782927  0.487212  ...  0.579363  0.560296  0.503951
# 191690  0.259230  0.789032  0.360820  ...  0.582955  0.563240  0.466597
# 44556   0.231536  0.790189  0.379263  ...  0.577613  0.604593  0.509057
# 123270  0.266281  0.787084  0.463120  ...  0.578819  0.556236  0.475774
#
#              V23       V24       V25       V26       V27       V28    Amount
# 76482   0.663067  0.497733  0.625622  0.374535  0.417204  0.314151  0.000039
# 13381   0.665305  0.432214  0.602376  0.351562  0.417511  0.313831  0.000389
# 137544  0.660564  0.201911  0.576246  0.427014  0.418426  0.315351  0.000412
# 213217  0.669554  0.467719  0.562931  0.391856  0.416306  0.311964  0.000973
# 95534   0.661494  0.290700  0.606636  0.629079  0.415982  0.313000  0.001242
# ...          ...       ...       ...       ...       ...       ...       ...
# 87354   0.664243  0.348098  0.551086  0.587447  0.398929  0.305202  0.000741
# 272150  0.667968  0.369732  0.564565  0.461002  0.415983  0.312765  0.002100
# 191690  0.664481  0.381289  0.597296  0.435994  0.425308  0.319694  0.000000
# 44556   0.660942  0.370592  0.548939  0.377244  0.420128  0.315988  0.000039
# 123270  0.663849  0.351916  0.609855  0.370721  0.418156  0.315404  0.000039
#
# [568630 rows x 30 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=7,test_size=0.2,shuffle=True)

# %%
history = ann_model.fit(X_train,y_train,epochs=15,validation_split=0.2,batch_size=32)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From k:\VS Code Python\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From k:\VS Code Python\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 11373/11373 [==============================] - 18s 1ms/step - loss: 0.1768 - accuracy: 0.9376 - val_loss: 0.1557 - val_accuracy: 0.9449
# Epoch 2/15
# 11373/11373 [==============================] - 15s 1ms/step - loss: 0.1514 - accuracy: 0.9448 - val_loss: 0.1363 - val_accuracy: 0.9497
# Epoch 3/15
# 11373/11373 [==============================] - 13s 1ms/step - loss: 0.1363 - accuracy: 0.9502 - val_loss: 0.1384 - val_accuracy: 0.9491
# Epoch 4/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.1216 - accuracy: 0.9554 - val_loss: 0.1207 - val_accuracy: 0.9533
# Epoch 5/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.1099 - accuracy: 0.9596 - val_loss: 0.0978 - val_accuracy: 0.9580
# Epoch 6/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.1018 - accuracy: 0.9628 - val_loss: 0.1169 - val_accuracy: 0.9573
# Epoch 7/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0954 - accuracy: 0.9653 - val_loss: 0.0880 - val_accuracy: 0.9691
# Epoch 8/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0887 - accuracy: 0.9680 - val_loss: 0.0799 - val_accuracy: 0.9723
# Epoch 9/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0842 - accuracy: 0.9702 - val_loss: 0.0947 - val_accuracy: 0.9643
# Epoch 10/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0797 - accuracy: 0.9725 - val_loss: 0.0987 - val_accuracy: 0.9633
# Epoch 11/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0754 - accuracy: 0.9751 - val_loss: 0.0609 - val_accuracy: 0.9838
# Epoch 12/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0704 - accuracy: 0.9783 - val_loss: 0.0700 - val_accuracy: 0.9787
# Epoch 13/15
# 11373/11373 [==============================] - 13s 1ms/step - loss: 0.0674 - accuracy: 0.9801 - val_loss: 0.0644 - val_accuracy: 0.9802
# Epoch 14/15
# 11373/11373 [==============================] - 13s 1ms/step - loss: 0.0644 - accuracy: 0.9822 - val_loss: 0.0670 - val_accuracy: 0.9818
# Epoch 15/15
# 11373/11373 [==============================] - 12s 1ms/step - loss: 0.0625 - accuracy: 0.9833 - val_loss: 0.0622 - val_accuracy: 0.9801

# %%
ann_model.evaluate(X_test,y_test)
# Out:
# 3554/3554 [==============================] - 3s 735us/step - loss: 0.0617 - accuracy: 0.9800
# [0.0617300383746624, 0.980022132396698]

# %%
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = [i+1 for i in range(len(train_acc))]

plt.figure(figsize=(12,9))
plt.subplot(2,1,1)
plt.plot(epochs,train_loss,'b',label="Train Loss")
plt.plot(epochs,val_loss,'g',label="Validation loss")
plt.title("Loss")
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.figure(figsize=(12,9))
plt.subplot(2,1,1)
plt.plot(epochs,train_acc,'b',label="Train Accuracy")
plt.plot(epochs,val_acc,'g',label="Validation Accuracy")
plt.title("Accuracy")
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
y_predicted = ann_model.predict(X_test)
y_predicted = (y_predicted>0.5)

print(classification_report(y_test,y_predicted))
# Out:
# 3554/3554 [==============================] - 3s 730us/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     56749
#            1       0.99      0.97      0.98     56977
#
#     accuracy                           0.98    113726
#    macro avg       0.98      0.98      0.98    113726
# weighted avg       0.98      0.98      0.98    113726

# %%
cm = confusion_matrix(y_test, y_predicted)
sns.heatmap(cm, annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title("ANN confusion matrix")
plt.show()

# %%
ann_model.save("credit_fruad_ANN_model.keras")
